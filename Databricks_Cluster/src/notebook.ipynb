# %% [markdown]
# # Default notebook
#
# This default notebook is executed using Databricks Workflows as defined in resources/Databricks_Cluster.job.yml.

# %%
print("This is my clsuter notebook")
# Out:
# This is my clsuter notebook
